# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import zipfile
import os
import json

# %%
path = os.chdir(os.getcwd() + '\data')
data = zipfile.ZipFile('open.zip')
data.namelist()
# Out:
# ['sample_submission.csv',
#  'test.csv',
#  'test/',
#  'test/TEST_000.png',
#  'test/TEST_001.png',
#  'test/TEST_002.png',
#  'test/TEST_003.png',
#  'test/TEST_004.png',
#  'test/TEST_005.png',
#  'test/TEST_006.png',
#  'test/TEST_007.png',
#  'test/TEST_008.png',
#  'test/TEST_009.png',
#  'test/TEST_010.png',
#  'test/TEST_011.png',
#  'test/TEST_012.png',
#  'test/TEST_013.png',
#  'test/TEST_014.png',
#  'test/TEST_015.png',
#  'test/TEST_016.png',
#  'test/TEST_017.png',
#  'test/TEST_018.png',
#  'test/TEST_019.png',
#  'test/TEST_020.png',
#  'test/TEST_021.png',
#  'test/TEST_022.png',
#  'test/TEST_023.png',
#  'test/TEST_024.png',
#  'test/TEST_025.png',
#  'test/TEST_026.png',
#  'test/TEST_027.png',
#  'test/TEST_028.png',
#  'test/TEST_029.png',
#  'test/TEST_030.png',
#  'test/TEST_031.png',
#  'test/TEST_032.png',
#  'test/TEST_033.png',
#  'test/TEST_034.png',
#  'test/TEST_035.png',
#  'test/TEST_036.png',
#  'test/TEST_037.png',
#  'test/TEST_038.png',
#  'test/TEST_039.png',
#  'test/TEST_040.png',
#  'test/TEST_041.png',
#  'test/TEST_042.png',
#  'test/TEST_043.png',
#  'test/TEST_044.png',
#  'test/TEST_045.png',
#  'test/TEST_046.png',
#  'test/TEST_047.png',
#  'test/TEST_048.png',
#  'test/TEST_049.png',
#  'test/TEST_050.png',
#  'test/TEST_051.png',
#  'test/TEST_052.png',
#  'test/TEST_053.png',
#  'test/TEST_054.png',
#  'test/TEST_055.png',
#  'test/TEST_056.png',
#  'test/TEST_057.png',
#  'test/TEST_058.png',
#  'test/TEST_059.png',
#  'test/TEST_060.png',
#  'test/TEST_061.png',
#  'test/TEST_062.png',
#  'test/TEST_063.png',
#  'test/TEST_064.png',
#  'test/TEST_065.png',
#  'test/TEST_066.png',
#  'test/TEST_067.png',
#  'test/TEST_068.png',
#  'test/TEST_069.png',
#  'test/TEST_070.png',
#  'test/TEST_071.png',
#  'test/TEST_072.png',
#  'test/TEST_073.png',
#  'test/TEST_074.png',
#  'test/TEST_075.png',
#  'test/TEST_076.png',
#  'test/TEST_077.png',
#  'test/TEST_078.png',
#  'test/TEST_079.png',
#  'test/TEST_080.png',
#  'test/TEST_081.png',
#  'test/TEST_082.png',
#  'test/TEST_083.png',
#  'test/TEST_084.png',
#  'test/TEST_085.png',
#  'test/TEST_086.png',
#  'test/TEST_087.png',
#  'test/TEST_088.png',
#  'test/TEST_089.png',
#  'test/TEST_090.png',
#  'test/TEST_091.png',
#  'test/TEST_092.png',
#  'test/TEST_093.png',
#  'test/TEST_094.png',
#  'test/TEST_095.png',
#  'test/TEST_096.png',
#  'test/TEST_097.png',
#  'test/TEST_098.png',
#  'test/TEST_099.png',
#  'train.csv',
#  'train/',
#  'train/TRAIN_000.png',
#  'train/TRAIN_001.png',
#  'train/TRAIN_002.png',
#  'train/TRAIN_003.png',
#  'train/TRAIN_004.png',
#  'train/TRAIN_005.png',
#  'train/TRAIN_006.png',
#  'train/TRAIN_007.png',
#  'train/TRAIN_008.png',
#  'train/TRAIN_009.png',
#  'train/TRAIN_010.png',
#  'train/TRAIN_011.png',
#  'train/TRAIN_012.png',
#  'train/TRAIN_013.png',
#  'train/TRAIN_014.png',
#  'train/TRAIN_015.png',
#  'train/TRAIN_016.png',
#  'train/TRAIN_017.png',
#  'train/TRAIN_018.png',
#  'train/TRAIN_019.png',
#  'train/TRAIN_020.png',
#  'train/TRAIN_021.png',
#  'train/TRAIN_022.png',
#  'train/TRAIN_023.png',
#  'train/TRAIN_024.png',
#  'train/TRAIN_025.png',
#  'train/TRAIN_026.png',
#  'train/TRAIN_027.png',
#  'train/TRAIN_028.png',
#  'train/TRAIN_029.png',
#  'train/TRAIN_030.png',
#  'train/TRAIN_031.png',
#  'train/TRAIN_032.png',
#  'train/TRAIN_033.png',
#  'train/TRAIN_034.png',
#  'train/TRAIN_035.png',
#  'train/TRAIN_036.png',
#  'train/TRAIN_037.png',
#  'train/TRAIN_038.png',
#  'train/TRAIN_039.png',
#  'train/TRAIN_040.png',
#  'train/TRAIN_041.png',
#  'train/TRAIN_042.png',
#  'train/TRAIN_043.png',
#  'train/TRAIN_044.png',
#  'train/TRAIN_045.png',
#  'train/TRAIN_046.png',
#  'train/TRAIN_047.png',
#  'train/TRAIN_048.png',
#  'train/TRAIN_049.png',
#  'train/TRAIN_050.png',
#  'train/TRAIN_051.png',
#  'train/TRAIN_052.png',
#  'train/TRAIN_053.png',
#  'train/TRAIN_054.png',
#  'train/TRAIN_055.png',
#  'train/TRAIN_056.png',
#  'train/TRAIN_057.png',
#  'train/TRAIN_058.png',
#  'train/TRAIN_059.png',
#  'train/TRAIN_060.png',
#  'train/TRAIN_061.png',
#  'train/TRAIN_062.png',
#  'train/TRAIN_063.png',
#  'train/TRAIN_064.png',
#  'train/TRAIN_065.png',
#  'train/TRAIN_066.png',
#  'train/TRAIN_067.png',
#  'train/TRAIN_068.png',
#  'train/TRAIN_069.png',
#  'train/TRAIN_070.png',
#  'train/TRAIN_071.png',
#  'train/TRAIN_072.png',
#  'train/TRAIN_073.png',
#  'train/TRAIN_074.png',
#  'train/TRAIN_075.png',
#  'train/TRAIN_076.png',
#  'train/TRAIN_077.png',
#  'train/TRAIN_078.png',
#  'train/TRAIN_079.png',
#  'train/TRAIN_080.png',
#  'train/TRAIN_081.png',
#  'train/TRAIN_082.png',
#  'train/TRAIN_083.png',
#  'train/TRAIN_084.png',
#  'train/TRAIN_085.png',
#  'train/TRAIN_086.png',
#  'train/TRAIN_087.png',
#  'train/TRAIN_088.png',
#  'train/TRAIN_089.png',
#  'train/TRAIN_090.png',
#  'train/TRAIN_091.png',
#  'train/TRAIN_092.png',
#  'train/TRAIN_093.png',
#  'train/TRAIN_094.png',
#  'train/TRAIN_095.png',
#  'train/TRAIN_096.png',
#  'train/TRAIN_097.png',
#  'train/TRAIN_098.png',
#  'train/TRAIN_099.png',
#  'train/TRAIN_100.png',
#  'train/TRAIN_101.png',
#  'train/TRAIN_102.png',
#  'train/TRAIN_103.png',
#  'train/TRAIN_104.png',
#  'train/TRAIN_105.png',
#  'train/TRAIN_106.png',
#  'train/TRAIN_107.png',
#  'train/TRAIN_108.png',
#  'train/TRAIN_109.png',
#  'train/TRAIN_110.png',
#  'train/TRAIN_111.png',
#  'train/TRAIN_112.png',
#  'train/TRAIN_113.png',
#  'train/TRAIN_114.png',
#  'train/TRAIN_115.png',
#  'train/TRAIN_116.png',
#  'train/TRAIN_117.png',
#  'train/TRAIN_118.png',
#  'train/TRAIN_119.png',
#  'train/TRAIN_120.png',
#  'train/TRAIN_121.png',
#  'train/TRAIN_122.png',
#  'train/TRAIN_123.png',
#  'train/TRAIN_124.png',
#  'train/TRAIN_125.png',
#  'train/TRAIN_126.png',
#  'train/TRAIN_127.png',
#  'train/TRAIN_128.png',
#  'train/TRAIN_129.png',
#  'train/TRAIN_130.png',
#  'train/TRAIN_131.png',
#  'train/TRAIN_132.png',
#  'train/TRAIN_133.png',
#  'train/TRAIN_134.png',
#  'train/TRAIN_135.png',
#  'train/TRAIN_136.png',
#  'train/TRAIN_137.png',
#  'train/TRAIN_138.png',
#  'train/TRAIN_139.png',
#  'train/TRAIN_140.png',
#  'train/TRAIN_141.png',
#  'train/TRAIN_142.png',
#  'train/TRAIN_143.png',
#  'train/TRAIN_144.png',
#  'train/TRAIN_145.png',
#  'train/TRAIN_146.png',
#  'train/TRAIN_147.png',
#  'train/TRAIN_148.png',
#  'train/TRAIN_149.png',
#  'train/TRAIN_150.png',
#  'train/TRAIN_151.png',
#  'train/TRAIN_152.png',
#  'train/TRAIN_153.png',
#  'train/TRAIN_154.png',
#  'train/TRAIN_155.png',
#  'train/TRAIN_156.png',
#  'train/TRAIN_157.png',
#  'train/TRAIN_158.png',
#  'train/TRAIN_159.png',
#  'train/TRAIN_160.png',
#  'train/TRAIN_161.png',
#  'train/TRAIN_162.png',
#  'train/TRAIN_163.png',
#  'train/TRAIN_164.png',
#  'train/TRAIN_165.png',
#  'train/TRAIN_166.png',
#  'train/TRAIN_167.png',
#  'train/TRAIN_168.png',
#  'train/TRAIN_169.png',
#  'train/TRAIN_170.png',
#  'train/TRAIN_171.png',
#  'train/TRAIN_172.png',
#  'train/TRAIN_173.png',
#  'train/TRAIN_174.png',
#  'train/TRAIN_175.png',
#  'train/TRAIN_176.png',
#  'train/TRAIN_177.png',
#  'train/TRAIN_178.png',
#  'train/TRAIN_179.png',
#  'train/TRAIN_180.png',
#  'train/TRAIN_181.png',
#  'train/TRAIN_182.png',
#  'train/TRAIN_183.png',
#  'train/TRAIN_184.png',
#  'train/TRAIN_185.png',
#  'train/TRAIN_186.png',
#  'train/TRAIN_187.png',
#  'train/TRAIN_188.png',
#  'train/TRAIN_189.png',
#  'train/TRAIN_190.png',
#  'train/TRAIN_191.png',
#  'train/TRAIN_192.png',
#  'train/TRAIN_193.png',
#  'train/TRAIN_194.png',
#  'train/TRAIN_195.png',
#  'train/TRAIN_196.png',
#  'train/TRAIN_197.png',
#  'train/TRAIN_198.png',
#  'train/TRAIN_199.png',
#  'train/TRAIN_200.png',
#  'train/TRAIN_201.png',
#  'train/TRAIN_202.png',
#  'train/TRAIN_203.png',
#  'train/TRAIN_204.png',
#  'train/TRAIN_205.png',
#  'train/TRAIN_206.png',
#  'train/TRAIN_207.png',
#  'train/TRAIN_208.png',
#  'train/TRAIN_209.png',
#  'train/TRAIN_210.png',
#  'train/TRAIN_211.png',
#  'train/TRAIN_212.png']

# %%
files = ['test.csv','train.csv','sample_submission.csv']
for file in files:
    data.extract(file)

# %%
sample_data = pd.read_csv('sample_submission.csv')
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#           id               img_path  label
# 0  TRAIN_000  ./train/TRAIN_000.png      0
# 1  TRAIN_001  ./train/TRAIN_001.png      0
# 2  TRAIN_002  ./train/TRAIN_002.png      0
# 3  TRAIN_003  ./train/TRAIN_003.png      0
# 4  TRAIN_004  ./train/TRAIN_004.png      0
